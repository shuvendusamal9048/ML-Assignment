# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('historical_data.csv')

# %%
df1=pd.read_csv('fear_greed_index.csv')

# %%
df.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %%
df.shape
# Out:
# (211224, 16)

# %%
df1.head(2)
# Out:
#     timestamp  value classification        date
# 0  1517463000     30           Fear  2018-02-01
# 1  1517549400     15   Extreme Fear  2018-02-02

# %%
df['Date']=pd.to_datetime(df['Timestamp IST'],format="%d-%m-%Y %H:%M").dt.date

# %%
df1['Date']=pd.to_datetime(df1['date']).dt.date

# %%
df.head(2)
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# 0         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 1         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
#
#    Crossed       Fee      Trade ID     Timestamp        Date
# 0     True  0.345404  8.950000e+14  1.730000e+12  2024-12-02
# 1     True  0.005600  4.430000e+14  1.730000e+12  2024-12-02

# %%
df1.head(2)
# Out:
#     timestamp  value classification        date        Date
# 0  1517463000     30           Fear  2018-02-01  2018-02-01
# 1  1517549400     15   Extreme Fear  2018-02-02  2018-02-02

# %%
df1.shape
# Out:
# (2644, 5)

# %%
merged_df=pd.merge(df,df1[['Date','classification']],on='Date',how='left')

# %%
merged_df.head(4)
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# 0         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 1         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# ...

# %%
merged_df.shape
# Out:
# (211224, 18)

# %%
merged_df.isnull().sum()
# Out:
# Account             0
# Coin                0
# Execution Price     0
# Size Tokens         0
# Size USD            0
# Side                0
# Timestamp IST       0
# Start Position      0
# Direction           0
# Closed PnL          0
# Transaction Hash    0
# Order ID            0
# Crossed             0
# Fee                 0
# Trade ID            0
# Timestamp           0
# Date                0
# classification      6
# dtype: int64

# %%
merged_df = merged_df.dropna(subset=["classification"])

# %%
merged_df.shape
# Out:
# (211218, 18)

# %%
merged_df.isnull().sum()
# Out:
# Account             0
# Coin                0
# Execution Price     0
# Size Tokens         0
# Size USD            0
# Side                0
# Timestamp IST       0
# Start Position      0
# Direction           0
# Closed PnL          0
# Transaction Hash    0
# Order ID            0
# Crossed             0
# Fee                 0
# Trade ID            0
# Timestamp           0
# Date                0
# classification      0
# dtype: int64

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
merged_df['Profit']=(merged_df['Closed PnL'] >0).astype(int)

# %%
merged_df.head(2)
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# 0         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 1         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
#
#    Crossed       Fee      Trade ID     Timestamp        Date classification  \
# 0     True  0.345404  8.950000e+14  1.730000e+12  2024-12-02  Extreme Greed
# 1     True  0.005600  4.430000e+14  1.730000e+12  2024-12-02  Extreme Greed
#
#    Profit
# 0       0
# 1       0

# %%
merged_df.sample(5)
# Out:
#                                            Account      Coin  Execution Price  \
# 202768  0x92f17e8d81a944691c10e753af1b1baae1a2cd0d      @107         22.44400
# 138319  0x28736f43f1e871e6aa8b1148d38d4994275d72c4       ENA          0.78172
# 144872  0x39cef799f8b69da1995852eea189df24eb5cae3c  FARTCOIN          0.72576
# 176633  0xbee1707d6b44d4d52bfe19e41f8a828645437aab      HYPE         15.99200
# 52269   0xb1231a4a2dd02f2276fa3c5e2a2f3436e6bfed23      HYPE         12.99000
#
#         Size Tokens  Size USD Side     Timestamp IST  Start Position  \
# 202768        20.00    448.88  BUY  08-02-2025 03:15     8010.348893
# 138319       191.00    149.31  BUY  27-01-2025 04:52     5895.000000
# 144872       163.80    118.88  BUY  09-04-2025 23:20   -19517.100000
# 176633       122.99   1966.86  BUY  07-03-2025 06:56     -840.760000
# 52269       1281.93  16652.27  BUY  12-03-2025 14:52    14067.650000
#
#           Direction  Closed PnL  \
# 202768          Buy    0.000000
# ...

# %%
#feature
features = ['Coin',"Execution Price", "Size USD", "Side", 'Start Position', "Fee", "classification",'Profit']

# %%
merged_df.sample(2)
# Out:
#                                            Account  Coin  Execution Price  \
# 46807   0xb1231a4a2dd02f2276fa3c5e2a2f3436e6bfed23   @51          1.98990
# 104403  0x8477e447846c758f5a675856001ea72298fd9cb5  TNSR          0.50536
#
#         Size Tokens  Size USD Side     Timestamp IST  Start Position  \
# 46807          80.0    159.19  BUY  29-01-2025 03:46     2253.181132
# 104403       1331.8    673.04  BUY  09-11-2024 22:26   -21174.400000
#
#           Direction  Closed PnL  \
# 46807           Buy    0.000000
# 104403  Close Short    3.169684
#
#                                          Transaction Hash     Order ID  \
# 46807   0x671317e032fa09f3a277041cb4af690203db00611e24...  67324090441
# 104403  0x100e712d7734f6bd57b50416630d9801af004ae283e3...  45621875378
#
#         Crossed       Fee      Trade ID     Timestamp        Date  \
# 46807      True  0.028000  5.290000e+14  1.740000e+12  2025-01-29
# 104403     True  0.235563  7.000000e+14  1.730000e+12  2024-11-09
#
# ...

# %%
fainal_df=merged_df[['Coin',"Execution Price", "Size USD", "Side",'Start Position', "Fee", "classification",'Profit']]

# %%
fainal_df.to_csv("Model_Data.csv",index=False)
